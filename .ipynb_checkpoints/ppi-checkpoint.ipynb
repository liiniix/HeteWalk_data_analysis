# %%
import pandas as pd

# %%
# !ls dataset/ppi
# Out:
# 1_BINARY_PROTEIN_PROTEIN_INTERACTIONS.txt  1.csv

# %%
df = pd.read_csv('dataset/ppi/1_BINARY_PROTEIN_PROTEIN_INTERACTIONS.txt', sep='\t')

# %%
df
# Out:
#       Interactor 1 Gene symbol  Interactor 1 HPRD id Interactor 1 RefSeq id  \
# 0                      ALDH1A1                     1            NP_000680.2
# 1                        ITGA7                  2761         NP_001138468.1
# 2                      PPP1R9A                 16000            NP_060120.2
# 3                         SRGN                  1513            NP_002718.2
# 4                         GRB7                  3311            NP_005301.2
# 5                         PAK1                  3995             AAC24716.1
# 6                         DLG4                  4199            NP_001356.1
# 7                       PIK3R2                  4404            NP_005018.1
# 8                       PTPN18                  5961            NP_055184.2
# 9                      ERBB2IP                  6090             AAK69431.1
# 10                      SMURF2                  6901            NP_073576.1
# ...

# %%
for_nx = df[['Interactor 1 HPRD id','Interactor 2 HPRD id']]

# %%
for_nx
# Out:
#        Interactor 1 HPRD id  Interactor 2 HPRD id
# 0                         1                     1
# 1                      2761                     7
# 2                     16000                    17
# 3                      1513                   115
# 4                      3311                  1281
# 5                      3995                  1281
# 6                      4199                  1281
# 7                      4404                  1281
# 8                      5961                  1281
# 9                      6090                  1281
# 10                     6901                  4060
# 11                     6980                  1281
# 12                     9004                  1281
# 13                     9218                  1281
# 14                     1525                   115
# 15                     9273                  1281
# 16                    11829                  1281
# 17                    16176                  1281
# ...

# %%
#for_nx.to_csv('1.csv', index=False, header=False,sep=';')
