# %%
import scipy.io

# %%
mat = scipy.io.loadmat('3_MimMiner_Exp_AC_T_TXCS_basedonACMESH_filt_RW.mat')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-8894b1c5f609> in <module>
# ----> 1 mat = scipy.io.loadmat('3_MimMiner_Exp_AC_T_TXCS_basedonACMESH_filt_RW.mat')
#
# /usr/lib/python3/dist-packages/scipy/io/matlab/mio.py in loadmat(file_name, mdict, appendmat, **kwargs)
#     132     """
#     133     variable_names = kwargs.pop('variable_names', None)
# --> 134     MR = mat_reader_factory(file_name, appendmat, **kwargs)
#     135     matfile_dict = MR.get_variables(variable_names)
#     136     if mdict is not None:
#
# /usr/lib/python3/dist-packages/scipy/io/matlab/mio.py in mat_reader_factory(file_name, appendmat, **kwargs)
#      56     """
#      57     byte_stream = _open_file(file_name, appendmat)
# ---> 58     mjv, mnv = get_matfile_version(byte_stream)
#      59     if mjv == 0:
#      60         return MatFile4Reader(byte_stream, **kwargs)
#
# ...

# %%
mat
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-70dcae91a5d5> in <module>
# ----> 1 mat
#
# NameError: name 'mat' is not defined

# %%
# !ls dataset/3
# Out:
# 3_MimMiner_Exp_AC_T_TXCS_basedonACMESH_filt_RW.mat
# 3_MimMiner_Exp_AC_T_TXCS_basedonACMESH_filt_RW.tsv

# %%
import pandas as pd

# %%
df = pd.read_csv("dataset/3/3_MimMiner_Exp_AC_T_TXCS_basedonACMESH_filt_RW.tsv")

# %%
df
# Out:
#      100050\t      1\t0.0890344\t0.361651\t0.266263\t0.368639\t0.197142\t0.0678806\t0.203997\t0.238039\t0.210782\t0.15004\t0.368094\t0.408045\t0.444959\t0.357986\t0.428706\t0.367318\t0.171618\t0.135908\t0.109824\t0.158275\t0.250779\t0.24102\t0.0969959\t0.0867458\t0.143905\t 0.2741\t0.191325\t0.314097\t0.32312\t0.265298\t0.127642\t0.0731327\t0.250465\t0.0603798\t0.159578\t0.104164\t0.0681626\t0.174627\t0.139357\t0.12265\t0.0644336\t0.318517\t0.254264\t0.177383\t0.17666\t0.241148\t0.238527\t0.243388\t0.219824\t0.104366\t0.174458\t0.0238355\t0.0481953\t0.141569\t0.114476\t0.0909451\t0.188525\t0.182661\t0.133912\t0.16892\t0.0178769\t0.360515\t0.154796\t0.13471\t0.211685\t0.113633\t0.137445\t0.109939\t0.252701\t0.12437\t0.178389\t0.145199\t0.181275\t0.0805591\t0.157982\t0.100839\t0.0283994\t0.118927\t0.101585\t0.0172539\t0.0984049\t0.227625\t0.173163\t0.104894\t0.0239928\t0.300295\t0.220613\t0.0556637\t0.23157\t0.183159\t0.183642\t0.19898\t0.153104\t0.135261\t0.161966\t0.393198\t0.418535\
# ...
